# %% [markdown]
# # **プログラミング1 課題03**
#
# - 出席番号: 05
# - 氏名: 稲葉 玲音
# - 課題03の取組み時間: 約420分

# %%
#演習1
# %reset -f

W = 512

def ghost_ship_message(x1: int, y1: int, x2: int, y2: int) -> str:#関数を利用した。
    assert all(0 <= v <= 511 for v in (x1, y1, x2, y2)), "座標が範囲外です"

    east,  west  = (x2 - x1) % W, (x1 - x2) % W
    south, north = (y2 - y1) % W, (y1 - y2) % W #

    h_dir, h_dist = ("東", east)  if east  <= west  else ("西", west)
    v_dir, v_dist = ("南", south) if south <= north else ("北", north)

    if h_dist == 0 and v_dist == 0:
        return '💀「幽霊船にであえたようじゃな」'

    parts = [f"{d}に{n}" for d, n in ((h_dir, h_dist), (v_dir, v_dist)) if n != 0]
    return f'💀「{"、".join(parts)}進めば幽霊船にであえるだろう」'#ここまで20分経過した。

cases = [
    (20, 10, 30,  5),
    (10, 10,  7, 13),
    (100, 490, 100, 510),
    (200, 200, 490, 200),
    (50,  50,  50,  50),
]

for x1, y1, x2, y2 in cases:
    print(f'({x1},{y1}) -> ({x2},{y2})')
    print(ghost_ship_message(x1, y1, x2, y2))
    print() #ここまで30分経過した。
# Out:
# (20,10) -> (30,5)
# 💀「東に10、北に5進めば幽霊船にであえるだろう」
#
# (10,10) -> (7,13)
# 💀「西に3、南に3進めば幽霊船にであえるだろう」
#
# (100,490) -> (100,510)
# 💀「南に20進めば幽霊船にであえるだろう」
#
# (200,200) -> (490,200)
# 💀「西に222進めば幽霊船にであえるだろう」
#
# (50,50) -> (50,50)
# 💀「幽霊船にであえたようじゃな」

# %%
# !pip install japanize_matplotlib
# Out:
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 49.5 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting matplotlib (from japanize_matplotlib)
#   Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->japanize_matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->japanize_matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->japanize_matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->japanize_matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting numpy>=1.23 (from matplotlib->japanize_matplotlib)
#   Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->japanize_matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib->japanize_matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib->japanize_matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->japanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)
# Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 45.5 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 54.3 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.3 MB/s  0:00:00
# Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 56.5 MB/s  0:00:006m0:00:01
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 45.0 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (pyproject.toml) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120306 sha256=c9146bf1ee14ff32defcc55b0b7fefca18d2170214030020c241ee58bb7144a0
#   Stored in directory: /home/codespace/.cache/pip/wheels/c1/f7/9b/418f19a7b9340fc16e071e89efc379aca68d40238b258df53d
# Successfully built japanize_matplotlib
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib, japanize_matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [japanize_matplotlib]tplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 japanize_matplotlib-1.1.3 kiwisolver-1.5.0 matplotlib-3.10.9 numpy-2.4.6 pillow-12.2.0 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
